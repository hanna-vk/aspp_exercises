# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
os.chdir('/content/gdrive/MyDrive/Colab Notebooks/ASPP Course/')
# Out:
# Mounted at /content/gdrive

# %%
# !nvidia-smi
# Out:
# Thu Mar 13 10:05:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import numpy as np
import cupy as cp

# %%
i = [1,2,4,8,16]

for n in i:

  array_np = np.random.rand(n*128,n*128)
  array_cp = cp.random.rand(n*128,n*128)

  time_np = %timeit -o np.fft.fft2(array_np)
  time_cp = %timeit -o cp.fft.fft2(array_cp)

  print('Size: ',array_np.shape,', Time numpy: ',time_np,', Time cupy: ',time_cp)
# Out:
# 229 µs ± 3.35 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 71.5 µs ± 1.19 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# Size:  (128, 128) , Time Numpy:  229 µs ± 3.35 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each) , Time Cupy:  71.5 µs ± 1.19 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.22 ms ± 222 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 82.2 µs ± 13.5 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# Size:  (256, 256) , Time Numpy:  1.22 ms ± 222 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each) , Time Cupy:  82.2 µs ± 13.5 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 5.15 ms ± 208 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 251 µs ± 100 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Size:  (512, 512) , Time Numpy:  5.15 ms ± 208 µs per loop (mean ± std. dev. of 7 runs, 100 loops each) , Time Cupy:  251 µs ± 100 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 28 ms ± 2.47 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.08 ms ± 57.2 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Size:  (1024, 1024) , Time Numpy:  28 ms ± 2.47 ms per loop (mean ± std. dev. of 7 runs, 10 loops each) , Time Cupy:  1.08 ms ± 57.2 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 157 ms ± 21.2 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 4.11 ms ± 24.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Size:  (2048, 2048) , Time Numpy:  157 ms ± 21.2 ms per loop (mean ± std. dev. of 7 runs, 10 loops each) , Time Cupy:  4.11 ms ± 24.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
i = [1,2,4,8,16]

for n in i:

  array_np = np.random.rand(n*128,n*128).astype(np.float32)
  array_cp = cp.random.rand(n*128,n*128)

  time_np = %timeit -o np.fft.fft2(array_np)
  time_cp = %timeit -o cp.fft.fft2(array_cp)

  print('Size: ',array_np.shape,', Time numpy: ',time_np,', Time cupy: ',time_cp)
# Out:
# 224 µs ± 4.94 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 71.2 µs ± 1.88 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# Size:  (128, 128) , Time numpy:  224 µs ± 4.94 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each) , Time cupy:  71.2 µs ± 1.88 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.13 ms ± 264 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 79.3 µs ± 15.1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# Size:  (256, 256) , Time numpy:  1.13 ms ± 264 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each) , Time cupy:  79.3 µs ± 15.1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 4.86 ms ± 50.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 251 µs ± 101 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Size:  (512, 512) , Time numpy:  4.86 ms ± 50.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each) , Time cupy:  251 µs ± 101 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 27.2 ms ± 604 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.08 ms ± 93.8 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Size:  (1024, 1024) , Time numpy:  27.2 ms ± 604 µs per loop (mean ± std. dev. of 7 runs, 10 loops each) , Time cupy:  1.08 ms ± 93.8 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 155 ms ± 15.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 4.16 ms ± 22.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Size:  (2048, 2048) , Time numpy:  155 ms ± 15.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each) , Time cupy:  4.16 ms ± 22.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
